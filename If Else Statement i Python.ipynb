# %%
#If Else satements in python


x=50
y=100

if x>y:
    print("x is greater than y")
elif y>x:
    print("y is greater than x")
    
else:
    print("OUT!")
# Out:
# y is greater than x

# %%
num =float(input("Enter any number: "))

if num % 2==0:
    if num % 5==0:
        print(num,"Divisible 5 and 2")
    else:
        print("Divisible only 2")
else:
    print("Not divisible")
# Out:
# Enter any number: 10
# 10.0 Divisible 5 and 2

# %%
from IPython.display import Image
Image("electrricity.JPG")

# %%
amount = 0

net_units =float(input("Enter your unit value: "))

if net_units<=100:
    amount=0
    print("Amount is:", amount)
    
elif net_units>100 and net_units <=200:
    amount=(net_units-100)*5
    print("Amount is: ", amount)
    
elif net_units>200:
    amount= (net_units-200)*10 +500
    print("Amount is: ", amount)
else:
    print(" Error")
# Out:
# Enter your unit value: 350
# Amount is:  2000.0
